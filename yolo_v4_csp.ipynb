# %%
import tensorflow as tf
from tensorflow import keras

# 实时更新导入的外部 python 程序
# %load_ext autoreload
# %autoreload 2

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
import yolo_v4_csp

# %%
model = yolo_v4_csp.create_model()
model.summary()
keras.utils.plot_model(model, to_file='yolo_v4_csp.png', 
                       show_shapes=True, dpi=1200)
# Out:
# Model: "yolo_v4_csp_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 608, 608, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 608, 608, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 608, 608, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  mish_activation (MishActivatio  (None, 608, 608, 32  0          ['batch_normalization[0][0]']
#  n)                             )
#
#  conv2d_1 (Conv2D)              (None, 304, 304, 64  18432       ['mish_activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 304, 304, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...
